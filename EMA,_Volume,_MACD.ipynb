# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import os
from google.colab import files
# %matplotlib inline
from matplotlib.pylab import rcParams
from plotly.subplots import make_subplots
rcParams['figure.figsize'] = 20,10

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06aa7ff1-4311-45dd-b421-324ce2414a34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06aa7ff1-4311-45dd-b421-324ce2414a34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving RELIANCE.NS.csv to RELIANCE.NS.csv

# %%
reli = pd.read_csv('RELIANCE.NS.csv')
reli = reli.set_index(pd.DatetimeIndex(reli['Date']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07ed774a83e5> in <module>()
# ----> 1 reli = pd.read_csv('RELIANCE.NS.csv')
#       2 reli = reli.set_index(pd.DatetimeIndex(reli['Date']))
#
# NameError: name 'pd' is not defined

# %%
print(reli)
# Out:
#                   Date         Open  ...    Adj Close      Volume
# Date                                 ...
# 2011-05-02  2011-05-02   487.330597  ...   438.769897   6280802.0
# 2011-05-03  2011-05-03   478.018860  ...   429.287262  10166156.0
# 2011-05-04  2011-05-04   468.063232  ...   430.992798   5384888.0
# 2011-05-05  2011-05-05   468.063232  ...   435.717133   9037540.0
# 2011-05-06  2011-05-06   472.025665  ...   438.056366   5960945.0
# ...                ...          ...  ...          ...         ...
# 2021-04-26  2021-04-26  1920.000000  ...  1937.849976   9620785.0
# 2021-04-27  2021-04-27  1940.000000  ...  1988.650024   9226547.0
# 2021-04-28  2021-04-28  1997.849976  ...  1997.300049   7902002.0
# 2021-04-29  2021-04-29  2022.900024  ...  2024.050049   8035915.0
# 2021-04-30  2021-04-30  2008.500000  ...  1994.500000   9150974.0
#
# [2469 rows x 7 columns]

# %%
reli.head()
# Out:
#                   Date        Open  ...   Adj Close      Volume
# Date                                ...
# 2011-05-02  2011-05-02  487.330597  ...  438.769897   6280802.0
# 2011-05-03  2011-05-03  478.018860  ...  429.287262  10166156.0
# 2011-05-04  2011-05-04  468.063232  ...  430.992798   5384888.0
# 2011-05-05  2011-05-05  468.063232  ...  435.717133   9037540.0
# 2011-05-06  2011-05-06  472.025665  ...  438.056366   5960945.0
#
# [5 rows x 7 columns]

# %%
reli['PriceDiff'] = reli['Close'].shift(-1) - reli['Close']
reli['DailyReturn'] =reli['PriceDiff'] / reli['Close']
print(reli)
# Out:
#                   Date         Open  ...  PriceDiff  DailyReturn
# Date                                 ...
# 2011-05-02  2011-05-02   487.330597  ... -10.327088    -0.021612
# 2011-05-03  2011-05-03   478.018860  ...   1.857391     0.003973
# 2011-05-04  2011-05-04   468.063232  ...   1.139191     0.002427
# 2011-05-05  2011-05-05   468.063232  ...   2.526062     0.005369
# 2011-05-06  2011-05-06   472.025665  ...   2.105042     0.004450
# ...                ...          ...  ...        ...          ...
# 2021-04-26  2021-04-26  1920.000000  ...  50.800048     0.026215
# 2021-04-27  2021-04-27  1940.000000  ...   8.650025     0.004350
# 2021-04-28  2021-04-28  1997.849976  ...  26.750000     0.013393
# 2021-04-29  2021-04-29  2022.900024  ... -29.550049    -0.014599
# 2021-04-30  2021-04-30  2008.500000  ...        NaN          NaN
#
# [2469 rows x 9 columns]

# %%
reli['Direction'] = [1 if reli['DailyReturn'].loc[ei] > 0 else 0 for ei in reli.index]

# %%
graph= {
        'x': reli.Date,
        'open': reli.Open,
        'close': reli.Close,
        'low': reli.Low,
        'high': reli.High,
        'type' :'candlestick'
        
                
}

# %%
reli['MA5'] = reli['Close'].rolling(window=3, min_periods=1).mean()
reli['MA13'] = reli['Close'].rolling(window=13, min_periods=1).mean()
reli['MA26'] = reli['Close'].rolling(window=26, min_periods=1).mean()

avg1= {
    'x': reli.Date,
    'y': reli.MA20,
    'type':'scatter',
    'mode':'lines',
    'line': {
        'width':1,
        'color': 'black'
    },
    'name':'Moving Average of 5 periods'

}

avg2= {
    'x': reli.Date,
    'y': reli.MA50,
    'type':'scatter',
    'mode':'lines',
    'line': {
        'width':1,
        'color': 'purple'
    },
    'name':'Moving Average of 13 periods'

}

avg3= {
    'x': reli.Date,
    'y': reli.MA200,
    'type':'scatter',
    'mode':'lines',
    'line': {
        'width':1,
        'color': 'orange'
    },
    'name':'Moving Average of 26 periods'

}



data=[graph, avg1, avg2, avg3]

layout= go.Layout({
    'title':{
        'text': 'RELIANCE NS (2011-2021)',
        'font': {
            'size':25
            
        }
    }
}
)

# %%
fig= go.Figure(data=data, layout=layout)
config = dict({'scrollZoom': True})
fig.show(config=config)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a73c5271-f8a1-4378-86cb-7f3a7a33fc5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a73c5271-f8a1-4378-86cb-7f3a7a33fc5c")) {
#                     Plotly.newPlot(
#                         'a73c5271-f8a1-4378-86cb-7f3a7a33fc5c',
#                         [{"close": [477.84549000000004, 467.518402, 469.375793, 470.51498399999997, 473.041046, 475.14608799999996, 470.911224, 473.239166, 468.310883, 469.549133, 468.063232, 456.002563, 446.69082599999996, 453.451721, 457.265564, 450.430359, 453.575562, 448.746338, 462.540588, 468.28610199999997, 465.01709000000005, 471.456055, 468.95477300000005, 471.05981399999996, 462.912048, 464.47225999999995, 474.626007, 470.143524, 472.520966, 467.815582, 458.45431500000007, 451.39620999999994, 446.046936, 439.607971, 430.29623399999997, 412.712891, 420.340576, 418.928986, 431.162994, 431.60879500000004, 431.683075, 431.460175, 438.46875, 445.03155499999997, 426.928162, 430.122864, 419.003265, 422.44564800000006, 431.262054, 423.41146900000007, 422.64376799999997, 419.89480599999996, 428.66171299999996, 429.701843, 432.50033600000006, 429.726624, 435.595978, 433.986237, 426.38330099999996, 432.57461500000005, 437.280029, 431.658325, 426.38330099999996, 414.743652, 410.087769, 411.52417, 414.71887200000003, 408.651398, 402.361023, 392.28155499999997, 386.659851, 379.056915, 382.746948, 382.474518, 376.877563, 376.01080299999995, 373.955292, 367.12005600000003, 362.835693
, 346.465851, 355.40609700000005, null, 349.809143, 364.643555, 370.611969, 364.99026499999997, 362.464203, 353.127716, 367.54107700000003, 386.214081, 389.136383, 392.603516, 382.152588, 388.19528199999996, 391.761505, 406.348236, 393.643646, 404.713715, 411.69751, 410.731659, 415.214172, 412.589081, 418.309845, 425.1698, 422.91616799999997, 417.665955, 420.637787, 420.46441699999997, 414.39694199999997, 402.410553, 405.258545, 417.814545, 412.787201, 415.858093, 406.125336, 387.05609100000004, 394.510437, 406.521576, 401.667603, 403.227814, null, 395.005737, 384.629089, 377.323364, 383.266998, 395.525818, 406.125336, 403.425934, 394.584717, 382.54882799999996, 374.00482200000005, 376.704224, 380.419006, 364.717834, 368.531677, 361.622192, 362.092712, 359.442841, 358.92276, 371.77594, 366.79812599999997, 372.816071, 369.992828, 367.590607, 367.838257, 361.721252, 368.160217, 372.24646, 370.53765899999996, 369.695648, 370.785339, 367.34295699999996, 361.993652, 364.693085, 364.09869399999997, 364.693085, 369.027008, 367.516327, 369.051758, 368.284027, 365.956116, 359.814331, 354.489777, 350.849304, 344.28649900000005, 343.815979, 345.32666, 337.451294, 337.624664, 334.875702, 339.358215, 341.042267, 344.484619, 342.305298, 340.200226, 344.385559, 342.354828, 347.53076200000004, 347.62982200000005, 349.809143, 349.487213, 339.40774500000003, 343.122528, 347.97653199999996, 354.588867, 357.238739, 361.424072, 357.734039, 358.08075, 354.786987, 354.811737, 359.962921, 356.074768, 365.26266499999997, 365.237915, 355.975708, 352.1618 ...

# %%
reli['MA12'] = reli['Close'].rolling(window=12, min_periods=1).mean()
reli['MA26'] = reli['Close'].rolling(window=26, min_periods=1).mean()
reli['macd'] = reli['MA12'] - reli['MA26']
reli['exp3'] = reli['macd'].rolling(window=9, min_periods=1).mean()

# %%
MACD1= {
    'x': reli.Date,
    'y': reli.macd,
    'type':'scatter',
    'mode':'lines',
    'line': {
        'width':1,
        'color': 'green'
    },
    'name':'MACD line'

}
signal= {
    'x': reli.Date,
    'y': reli.exp3,
    'type':'scatter',
    'mode':'lines',
    'line': {
        'width':1,
        'color': 'red'
    },
    'name':'Signal Line'

}


data=[MACD1,signal]

layout= go.Layout({
    'title':{
        'text': 'RELIANCE NS (2011-2021) MACD & Signal',
        'font': {
            'size':25
            
        }
    }
}
)

fig= go.Figure(data=data, layout=layout)
fig.update_layout(xaxis_rangeslider_visible=True)
config = dict({'scrollZoom': True})
fig.show(config=config)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff5e7483-c963-4e39-be34-cf2d768b318e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("